# %%
# %run q_learning_agent.py
# Out:
# episode   500  avg_return=  3.93  default_rate=19.4%  epsilon=0.97  states_visited=1056
# episode  1000  avg_return=  2.86  default_rate=21.4%  epsilon=0.95  states_visited=1465
# episode  1500  avg_return=  3.85  default_rate=22.4%  epsilon=0.92  states_visited=1742
# episode  2000  avg_return=  3.16  default_rate=24.6%  epsilon=0.89  states_visited=1962
# episode  2500  avg_return=  5.06  default_rate=20.2%  epsilon=0.87  states_visited=2098
# episode  3000  avg_return=  5.09  default_rate=20.2%  epsilon=0.84  states_visited=2223
# episode  3500  avg_return=  6.75  default_rate=15.8%  epsilon=0.82  states_visited=2331
# episode  4000  avg_return=  4.85  default_rate=22.2%  epsilon=0.79  states_visited=2419
# episode  4500  avg_return=  5.63  default_rate=21.4%  epsilon=0.76  states_visited=2495
# episode  5000  avg_return=  6.00  default_rate=20.0%  epsilon=0.74  states_visited=2581
# episode  5500  avg_return=  5.98  default_rate=18.6%  epsilon=0.71  states_visited=2634
# ...

# %%
# %run evaluate_new.py
# Out:
#                default rate   avg recovery   avg return
# rl                   11.0%         89.7%       11.78
# baseline             23.3%         90.1%       18.52
#
# --- Sample trajectories (RL policy) ---
#
# Borrower type: trader  |  outcome: repaid  |  recovery rate: 87%
#   month  0: action=reduce_extend  paid    1202/   1700  [no stress signals]
#   month  1: action=reduce_extend  paid    1723/   1723  [below seasonal expectation]
#   month  2: action=maintain       paid    1438/   2077  [no stress signals]
#   month  3: action=maintain       paid    2114/   2114  [below seasonal expectation]
#   month  4: action=maintain       paid    2114/   2114  [no stress signals]
#   month  5: action=reduce_extend  paid    1698/   1698  [no stress signals]
#   month  6: action=reduce_extend  paid    1698/   1698  [no stress signals]
#   month  7: action=reduce_extend  paid    1698/   1698  [no stress signals]
# ...

# %%
# %run review.py
